# %% [markdown]
# ### Trabalho de Sistemas Distribuidos
# #### Aluno: David Marcos

# %% [markdown]
# ### - Resolução do Problema de network embedding utilizando algoritimos geneticos

# %% [markdown]
# ### - importando bibliotecas

# %%
from random import sample,randint,random
import networkx as nx
from matplotlib import pyplot as plt

# %% [markdown]
# ### 1 -  passo criar grafo da rede fisica

# %% [markdown]
# ### criando nos da rede com seus respequitivos valores de cpu

# %%
rd_fisica =  nx.Graph()

rd_fisica.add_nodes_from([

    (0, {"cpu": 60}),
    (1, {"cpu": 70}),
    (2, {"cpu": 65}),
    (3, {"cpu": 70}),
    (4, {"cpu": 65}),

    (5, {"cpu": 52}),
    (6, {"cpu": 83}),
    (7, {"cpu": 99}),
    (8, {"cpu": 88}),
    (9, {"cpu": 98}),
    (10, {"cpu": 70}),
    (11, {"cpu": 50}),

    (12, {"cpu": 88}),
    (13, {"cpu": 98}),
    (14, {"cpu": 70}),
    (15, {"cpu": 50}),
    (16, {"cpu": 50}),
    (17, {"cpu": 90}),
    (18, {"cpu": 90}),
    (19, {"cpu": 95}),
    

])

# %% [markdown]
# ### definindo as arestas entre os nos com seus respequitivos valores dos links

# %%
"""rd_fisica.add_weighted_edges_from([
    (0,2,30),(0,3,50),(2,1,55),
    (1,4,43),(3,5,70),(3,6,60),
    (5,4,90),(5,6,45),(5,7,57),
    (4,7,66),(6,8,80),(6,9,77),
    (8,7,39),(7,10,48),(9,10,50),
    (8,10,45),(9,8,32),(9,11,32),
    (10,11,45),
    
    
    
    ]
)"""


rd_fisica.add_weighted_edges_from([
    (0,2,30),(0,3,50),(5,0,60),
    (2,1,55),(1,4,43),(3,5,70),
    (3,6,70),(5,2,90),(5,1,60),
    (7,6,60),(5,4,90),(5,6,45),
    (5,7,57),(4,7,66),(6,8,80),
    (6,9,77),(8,7,39),(7,10,48),
    (3,2,50),(8,10,45),(8,12,45),
    (10,11,45),(12,9,77),(10,14,70),
    (10,19,75),(8,19,75),(12,19,70),(11,19,85),
    (3,7,66),(6,12,80),(12,11,77),
    (11,14,39),(10,13,48),(11,10,45),
    (7,13,45),(4,13,72),(14,13,72),
    (8,13,72),(15,13,75),(14,15,66),
    (16,15,90),(16,18,80),(14,18,70),
    (15,18,85),(17,18,80),(9,8,72),
    (17,16,82),(17,14,92),(17,11,62),
       
    ]
)

# %% [markdown]
# ### plotando mapa da rede fisica

# %%
def plotar_rede(rd):
    edge_labels = dict([((n1, n2), [rd.get_edge_data(n1,n2)['weight']][0]) for n1, n2 in rd.edges])
    pos = nx.spring_layout(rd)
    plt.figure()

    nx.draw(
        rd, pos, edge_color='black', width=1, linewidths=1,
        node_size=500, node_color='blue', alpha=0.9,
        labels={node: node for node in rd.nodes()}
    )
    nx.draw_networkx_edge_labels(
        rd, pos,
        edge_labels=edge_labels,
        font_color='red'
    )


    plt.figure(figsize=(10,6))
    plt.show()

# %%
plotar_rede(rd_fisica)

# %% [markdown]
# ### - definindo uma função de avaliação

# %%
"""
    essa função recebe uma lista de nos que é uma possibilidade de solução
    e faz o mapeamento entre os nos com base nos enlaces da rede virtual,
    essa função retorna uma lista com os enlaces do mapeamento da rede
    virtual na rede fisica.

    obs: se ouver enlaces repetidos no mapeamento ou a quantidade de enlaces mapeados
    for menor que a quantidade de enlaces da rede virtual, quer dizer que não
    é possivel ter um bom mapeamento entre os nos, que atenda a topologia,
    da rede virtual
"""

def mapeamento_dos_nos(lista_nos,rd_virtual):
    map = []
    i = 0
    for edge in rd_virtual.edges():
        caminho = nx.single_source_shortest_path(rd_fisica, lista_nos[edge[0]])
        map.append(caminho[lista_nos[edge[1]]])
        i+=1

        #print(caminho)

    return map

# %%
# Definição do grafo de topologia virtual a ser mapeado
rd_virtual = nx.Graph()

rd_virtual.add_nodes_from([
    (0, {"cpu": 100}),
    (1, {"cpu": 400}),
    (2, {"cpu": 800}),
    (3, {"cpu": 150}),
    ]
    
    )

rd_virtual.add_weighted_edges_from([(0, 1,100),(0,2,80),(2,3,120)])

# %%
#mudançãs feitas aqui

def fitness(lista_nos,rd_fisica,rd_virtual):

    map = mapeamento_dos_nos(lista_nos,rd_virtual)


    lista_enlaces = []
    nos_cobrados = []

    num_enlaces = 0
    pontuacao = 0
    punicao = 2
    total_cpu = 0
    total_enlace = 0
    
    enlaces_virtuais = list(rd_virtual.edges(data=True))

    for enlace in map:
        for i in range(len(enlace)-1):
            
            en = sorted([enlace[i],enlace[i+1]])

            #print(f'(enlace_f:{[((enlace[i],rd_fisica.nodes[enlace[i]]),(enlace[i+1],rd_fisica.nodes[enlace[i+1]])) ,rd_fisica.get_edge_data(enlace[i],enlace[i+1]) ] })'
            #,f'enlace_v: {[((enlaces_virtuais[num_enlaces][0],rd_virtual.nodes[enlaces_virtuais[num_enlaces][0]]),(enlaces_virtuais[num_enlaces][1],rd_virtual.nodes[enlaces_virtuais[num_enlaces][1]])),enlaces_virtuais[num_enlaces][2]]}')
               
            #verifica se a capacidade do enlace atende aos requisitos da rede virtual ou se possui enlaces repetidos no mapeamento
            if  (en in lista_enlaces):
                #se entrar nesse if indica que o mapeamento dos nos é invalido
                punicao += 1000    
            
            if (rd_fisica.get_edge_data(enlace[i],enlace[i+1])['weight'] >=  enlaces_virtuais[num_enlaces][2]['weight']) :

                #subtrai o recurso do enlace virtual na rede fisica e contabiliza o restante do enlace    
                total_enlace+= rd_fisica.get_edge_data(enlace[i],enlace[i+1])['weight'] - enlaces_virtuais[num_enlaces][2]['weight']
            else:
                punicao += 1000
            

            #verifica se o no do enlace ja teve seu recurso de cpu contabilizado
            if enlace[i] not in nos_cobrados:
                '''
                se o no não foi contabilizado, verifica se o recurso de cpu do no atende aos requisitos do seu respequitivo
                no virtual, se possuir é subtraidos o valor do cpu virtual no no fisico e é contabilizado o total de cpu 
                restante do no fisico e o no é adicionado numa lista para indicar que o recurso de cpu ja foi contabilizado 
                '''
                if (rd_fisica.nodes[enlace[i]]['cpu'] >= rd_virtual.nodes[enlaces_virtuais[num_enlaces][0]]['cpu']):    
                    
                    total_cpu += rd_fisica.nodes[enlace[i]]['cpu'] - rd_virtual.nodes[enlaces_virtuais[num_enlaces][0]]['cpu']          
                    
                else:

                    punicao += 1000
                
                nos_cobrados.append(enlace[i])
        
            #faz a mesma operação acima so que com o outro no do enlace               
            if enlace[i+1] not in nos_cobrados:
                if(rd_fisica.nodes[enlace[i+1]]['cpu'] >= rd_virtual.nodes[enlaces_virtuais[num_enlaces][1]]['cpu']):
                    
                    total_cpu += rd_fisica.nodes[enlace[i+1]]['cpu'] - rd_virtual.nodes[enlaces_virtuais[num_enlaces][1]]['cpu']
                else:
                    punicao += 1000 
            
                nos_cobrados.append(enlace[i+1])

            lista_enlaces.append(en)     

        num_enlaces+=1


    """
    calcula a pontuação total do mapeamento, se for maior ou igual a 0 quer dizer que é possivel
    atender a requisição da rede virtual

    pontuação é calculada pelo total de cpu + total do enlace da rede fisica dividido pela
    quantidade de enlaces fisicos mapeados para a rede virtual + quantidade de Nós fisicos mapeados
    para a rede virtual - a punição

    se o enlace ou cpu nao possuir recursos suficientes para atender a rede virtual é acrescentado
    1000 de punição, se o mapeamento entre os enlaces for invalido  é acrescentado 1000 de punição que
    será decrementado da pontuação final
    """
    enlaces_mapeados = len(lista_enlaces) - rd_virtual.number_of_edges()
    nos_mapeados = len(nos_cobrados) - rd_virtual.number_of_nodes()

    pontuacao += (total_cpu + total_enlace - punicao) / (pow(enlaces_mapeados + nos_mapeados,3)+1)

    
    return pontuacao

# %%
mapeamento_dos_nos([16, 15, 13, 14],rd_virtual)
# Out:
# [[16, 15], [16, 15, 13], [13, 14]]

# %%
#fitness([16, 15, 13, 14],rd_fisica,rd_virtual)

# %%
(100 + 200 - 0) / pow(0 + 0+1,3)
# Out:
# 300.0

# %%
pow(0,3)
# Out:
# 0

# %% [markdown]
# ### -Definindo uma função para seleção dos individuos para crossover

# %%
""" 
    Função de seleção de pais com base em torneio,
    essa função seleciona dois individuos da população
    para isso é sorteado 4 individuos aleatorios da população
    e é selecionado o individuo que possui maior aptidão
"""
def tournament_selection(pontuacao, k=4):
    pais = []
    for i in range(2):
        candidatos = sample(pontuacao, k)
        
        melhor = max(candidatos)
        
        pais.append(melhor[1])
    
    return pais

# %% [markdown]
# ### -Definindo uma função para o cruzamento de individos

# %%
"""
    essa função faz o cruzamento entre dois individuos
    e é gerado um filho, para isso é sorteado um valor
    aleatorio de 0 a 1, se o valor for menor que 0,5 o filho
    recebe um no do pai1 se o valor for maior o filho recebe o 
    um no do pai2

"""
def crossover_uniforme(pai1, pai2):
    filho = []

    for i in range(len(pai1)):
        if random() < 0.5 and (pai1[i] not in(filho)):
            filho.append(pai1[i])
        else:
            if pai2[i] not in filho:
                filho.append(pai2[i])
            else:
                filho.append(pai1[i])
            
    return filho

# %% [markdown]
# ### -Definindo uma função para mutação de um individuo

# %%
"""
    essa função recebe um individuo e uma probabilidade de mutação
    se a probabilidade for atingida é trocado a posição dos nos
    do individuo
"""
def mutacao(lista_nos, prob_mutacao):
    if random() < prob_mutacao:
        pos1 = randint(0, len(lista_nos)-1)
        pos2 = randint(0, len(lista_nos)-1)

        lista_nos[pos1], lista_nos[pos2] = lista_nos[pos2], lista_nos[pos1]
    
    return lista_nos

# %% [markdown]
# ### -Definindo uma população inicial

# %%
def gera_populacao(pop_size,rd_virtual):
    """
        para gerar uma população é sorteado nos aleatorios da rede fisica,
        que são possiveis mapeamentos da requisição
    """
    nos_virtuais = len(rd_virtual.nodes)
    pop = []


    while(len(pop) < pop_size):
        nos_sorteados = sample(range(0, len(rd_fisica.nodes)), nos_virtuais)
        if nos_sorteados not in(pop):
            pop.append(nos_sorteados)
        #print(nos_sorteados)
    
    return pop

# %% [markdown]
# ### - Algoritmos Genético

# %%
def calculo_fitness(populacao,rd_fisica,rd_virtual):
    pontuacao = []
    for i in populacao:
        pontuacao.append([fitness(i,rd_fisica,rd_virtual),i])
    
    return pontuacao

# %% [markdown]
# ### Versão Sem Paralelismo

# %%
def evolucao(pontuacao):
        """
        Evolui a população para uma nova geração, retorna
        a população evoluida.
        """

        new_pop = []
        while len(new_pop) < len(pontuacao):
            
            pais = tournament_selection(pontuacao)

            filho = crossover_uniforme(pais[0],pais[1])
            filho = mutacao(filho,0.10)
    
            if filho not in new_pop and len(filho) == len(set(filho)):
                new_pop.append(filho)
        
        return new_pop

# %%
#mudançãs feitas aqui

def algoritimo_genetico(rd_fisica,rd_virtual):
    
    num_geracoes = 100
    pop_size = 600

    pop = gera_populacao(pop_size,rd_virtual)

    m_pontuacao = -1

    for i in range(num_geracoes):
        print(f'Geração {i+1}: ')
        print('*'*100)
        
        pontuacao = calculo_fitness(pop,rd_fisica,rd_virtual)
        
        pontuacao = sorted(pontuacao,reverse=True)

        m_pontuacao = pontuacao[0][0]
        individuo = pontuacao[0][1]
        mapeamento = mapeamento_dos_nos(individuo,rd_virtual)

        print(f'individuo = {individuo}, mapeamento= {mapeamento},melhor pontuação: {m_pontuacao}')

        pop = [pontuacao[i][1] for i in range(10)] + evolucao(pontuacao[10:])

    #se a pontuação for negativa quer dizer que não foi encontrada um mapeamento
    if m_pontuacao >= 0:    
        return [individuo,mapeamento]
    else:
        return []

# %% [markdown]
# ### Simulando o incorporamento da rede virtual na rede fisica

# %%
"""
    essa função é responsavel por receber mapeamento dos nos fisicos,
    que serão usados para atender a requisição da rede virtual e é
    responsavel por subtrair os recursos da rede virtual na rede fisica
    simulando o incorporamento da rede virtual na rede fisica.

"""
def consume_recursos(map,rd_fisica,rd_virtual):

    nos_cobrados = []
    enlaces = []

    num_enlaces = 0
    
    enlaces_virtuais = list(rd_virtual.edges(data=True))

    for enlace in map:
        for i in range(len(enlace)-1):
        
            #verifica se o no do enlace ja teve seu recurso de cpu contabilizado
            if enlace[i] not in nos_cobrados:
                    
                rd_fisica.nodes[enlace[i]]['cpu'] -= rd_virtual.nodes[enlaces_virtuais[num_enlaces][0]]['cpu']
                
                nos_cobrados.append(enlace[i])
        
            #faz a mesma operação acima so que com o outro no do enlace               
            if enlace[i+1] not in nos_cobrados:
                rd_fisica.nodes[enlace[i+1]]['cpu'] -= rd_virtual.nodes[enlaces_virtuais[num_enlaces][1]]['cpu']
                nos_cobrados.append(enlace[i+1])
                    
            rd_fisica.get_edge_data(enlace[i],enlace[i+1])['weight'] -= enlaces_virtuais[num_enlaces][2]['weight']

            enlaces.append(sorted((enlace[i],enlace[i+1])))
    
    return nos_cobrados,enlaces

# %%
def plotar_rede_incorporada(rd_fisica,nos_mapeados,enlaces_mapeados):
        
    edge_labels = dict([((n1, n2), [rd_fisica.get_edge_data(n1,n2)['weight']][0]) for n1, n2 in rd_fisica.edges])
    pos = nx.spring_layout(rd_fisica)
    plt.figure()

    node_colors = []
    for node in rd_fisica.nodes():
        if node in nos_mapeados:
            node_colors.append('red')
        else:
            node_colors.append('blue')


    edge_colors = []
    for edge in rd_fisica.edges():
        if list(edge) in enlaces_mapeados:
            edge_colors.append('red')
        else:
            edge_colors.append('black')


    nx.draw(
        rd_fisica, pos, edge_color=edge_colors, width=1, linewidths=1,
        node_size=500, node_color=node_colors, alpha=0.9,
        labels={node: node for node in rd_fisica.nodes()}
    )

    nx.draw_networkx_edge_labels(
        rd_fisica, pos,
        edge_labels=edge_labels,
        font_color='black'
    )


    plt.figure(figsize=(10,6))
    plt.show()

# %% [markdown]
# ### - Testando Algoritimo

# %% [markdown]
# ### 2 - Criando uma rede virtual

# %%
# Definição do grafo de topologia virtual a ser mapeado
rd_virtual = nx.Graph()

rd_virtual.add_nodes_from([
    (0, {"cpu": 15}),
    (1, {"cpu": 20}),
    (2, {"cpu": 25}),
    (3, {"cpu": 19}),
    ]
    
    )

rd_virtual.add_weighted_edges_from([(0, 1,14),(0,3,18),(0,2,12),
                                    (1, 2,15),(1,3,20),(2,3,20),])

# %%
plotar_rede(rd_virtual)

# %% [markdown]
# ### Execultando algoritimo Genetico

# %%
individuo = algoritimo_genetico(rd_fisica,rd_virtual)
# Out:
# Geração 1:
# ****************************************************************************************************
# individuo = [1, 5, 7, 3], mapeamento= [[1, 5], [1, 2, 3], [1, 4, 7], [5, 7], [5, 3], [7, 3]],melhor pontuação: 9.753846153846155
# Geração 2:
# ****************************************************************************************************
# individuo = [1, 5, 7, 3], mapeamento= [[1, 5], [1, 2, 3], [1, 4, 7], [5, 7], [5, 3], [7, 3]],melhor pontuação: 9.753846153846155
# Geração 3:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 4:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 5:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 6:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 7:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 8:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 9:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 10:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 11:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 12:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 13:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 14:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 15:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 16:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 17:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 18:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 19:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 20:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 21:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 22:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 23:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 24:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 25:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 26:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 27:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 28:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 29:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 30:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 31:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 32:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 33:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 34:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 35:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 36:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 37:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 38:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 39:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 40:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 41:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 42:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 43:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 44:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 45:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 46:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 47:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 48:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 49:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 50:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 51:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 52:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 53:
# ****************************************************************************************************
# individuo = [9, 8, 12, 6], mapeamento= [[9, 8], [9, 6], [9, 12], [8, 12], [8, 6], [12, 6]],melhor pontuação: 608.0
# Geração 54:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 55:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 56:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 57:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 58:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 59:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 60:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 61:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 62:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 63:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 64:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 65:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 66:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 67:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 68:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 69:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 70:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 71:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 72:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 73:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 74:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 75:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 76:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 77:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 78:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 79:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 80:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 81:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 82:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 83:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 84:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 85:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 86:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 87:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 88:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 89:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 90:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 91:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 92:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 93:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 94:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 95:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 96:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 97:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 98:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 99:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0
# Geração 100:
# ****************************************************************************************************
# individuo = [9, 12, 8, 6], mapeamento= [[9, 12], [9, 6], [9, 8], [12, 8], [12, 6], [8, 6]],melhor pontuação: 608.0

# %% [markdown]
# ### - Incorporando rede virtual na rede fisica

# %%
nos_mapeados,enlaces_mapeados = consume_recursos(individuo[1],rd_fisica,rd_virtual)

# %%
plotar_rede_incorporada(rd_fisica,nos_mapeados,enlaces_mapeados)

# %% [markdown]
# ### - Teste 2

# %%
# Definição do grafo de topologia virtual a ser mapeado
rd_virtual = nx.Graph()

rd_virtual.add_nodes_from([
    (0, {"cpu": 5}),
    (1, {"cpu": 4}),
    (2, {"cpu": 5}),
    (3, {"cpu": 9}),
    ]
    
    )

rd_virtual.add_weighted_edges_from([(0, 1,10),(0,2,8),(2,3,12),
                                    (1, 3,10)])

# %%
plotar_rede(rd_virtual)

# %%
i = algoritimo_genetico(rd_fisica,rd_virtual)

n,e = consume_recursos(i[1],rd_fisica,rd_virtual)
# Out:
# Geração 1:
# ****************************************************************************************************
# individuo = [19, 12, 8, 6], mapeamento= [[19, 12], [19, 8], [12, 6], [8, 6]],melhor pontuação: 506.0
# Geração 2:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 3:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 4:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 5:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 6:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 7:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 8:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 9:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 10:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 11:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 12:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 13:
# ****************************************************************************************************
# individuo = [19, 8, 10, 13], mapeamento= [[19, 8], [19, 10], [8, 13], [10, 13]],melhor pontuação: 536.0
# Geração 14:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 15:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 16:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 17:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 18:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 19:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 20:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 21:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 22:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 23:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 24:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 25:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 26:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 27:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 28:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 29:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 30:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 31:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 32:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 33:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 34:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 35:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 36:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 37:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 38:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 39:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 40:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 41:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 42:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 43:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 44:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 45:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 46:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 47:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 48:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 49:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 50:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 51:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 52:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 53:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 54:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 55:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 56:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 57:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 58:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 59:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 60:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 61:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 62:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 63:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 64:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 65:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 66:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 67:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 68:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 69:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 70:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 71:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 72:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 73:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 74:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 75:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 76:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 77:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 78:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 79:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 80:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 81:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 82:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 83:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 84:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 85:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 86:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 87:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 88:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 89:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 90:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 91:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 92:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 93:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 94:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 95:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 96:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 97:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 98:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 99:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0
# Geração 100:
# ****************************************************************************************************
# individuo = [19, 10, 8, 13], mapeamento= [[19, 10], [19, 8], [10, 13], [8, 13]],melhor pontuação: 536.0

# %%
plotar_rede_incorporada(rd_fisica,n,e)

# %% [markdown]
# ### - Teste 3

# %%
# Definição do grafo de topologia virtual a ser mapeado
rd_virtual = nx.Graph()

rd_virtual.add_nodes_from([
    (0, {"cpu": 100}),
    (1, {"cpu": 400}),
    (2, {"cpu": 800}),
    (3, {"cpu": 150}),
    ]
    
    )

rd_virtual.add_weighted_edges_from([(0, 1,100),(0,2,80),(2,3,120)])

# %%
plotar_rede(rd_virtual)

# %%
i = algoritimo_genetico(rd_fisica,rd_virtual)

if i :
    n,e = consume_recursos(i[1],rd_fisica,rd_virtual)
else:
    print("Nao foi possivel mapear rede virtual")
# Out:
# Geração 1:
# ****************************************************************************************************
# individuo = [16, 19, 2, 18], mapeamento= [[16, 17, 11, 19], [16, 15, 13, 7, 5, 2], [2, 1, 4, 13, 14, 18]],melhor pontuação: -3.4959183673469387
# Geração 2:
# ****************************************************************************************************
# individuo = [16, 19, 2, 18], mapeamento= [[16, 17, 11, 19], [16, 15, 13, 7, 5, 2], [2, 1, 4, 13, 14, 18]],melhor pontuação: -3.4959183673469387
# Geração 3:
# ****************************************************************************************************
# individuo = [16, 19, 2, 18], mapeamento= [[16, 17, 11, 19], [16, 15, 13, 7, 5, 2], [2, 1, 4, 13, 14, 18]],melhor pontuação: -3.4959183673469387
# Geração 4:
# ****************************************************************************************************
# individuo = [17, 9, 2, 16], mapeamento= [[17, 11, 12, 9], [17, 14, 10, 7, 5, 2], [2, 1, 4, 13, 15, 16]],melhor pontuação: -3.122109736282965
# Geração 5:
# ****************************************************************************************************
# individuo = [17, 9, 2, 16], mapeamento= [[17, 11, 12, 9], [17, 14, 10, 7, 5, 2], [2, 1, 4, 13, 15, 16]],melhor pontuação: -3.122109736282965
# Geração 6:
# ****************************************************************************************************
# individuo = [17, 9, 2, 16], mapeamento= [[17, 11, 12, 9], [17, 14, 10, 7, 5, 2], [2, 1, 4, 13, 15, 16]],melhor pontuação: -3.122109736282965
# Geração 7:
# ****************************************************************************************************
# individuo = [17, 9, 2, 16], mapeamento= [[17, 11, 12, 9], [17, 14, 10, 7, 5, 2], [2, 1, 4, 13, 15, 16]],melhor pontuação: -3.122109736282965
# Geração 8:
# ****************************************************************************************************
# individuo = [17, 9, 2, 16], mapeamento= [[17, 11, 12, 9], [17, 14, 10, 7, 5, 2], [2, 1, 4, 13, 15, 16]],melhor pontuação: -3.122109736282965
# Geração 9:
# ****************************************************************************************************
# individuo = [17, 9, 2, 16], mapeamento= [[17, 11, 12, 9], [17, 14, 10, 7, 5, 2], [2, 1, 4, 13, 15, 16]],melhor pontuação: -3.122109736282965
# Geração 10:
# ****************************************************************************************************
# individuo = [17, 9, 2, 16], mapeamento= [[17, 11, 12, 9], [17, 14, 10, 7, 5, 2], [2, 1, 4, 13, 15, 16]],melhor pontuação: -3.122109736282965
# Geração 11:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 12:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 13:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 14:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 15:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 16:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 17:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 18:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 19:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 20:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 21:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 22:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 23:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 24:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 25:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 26:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 27:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 28:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 29:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 30:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 31:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 32:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 33:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 34:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 35:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 36:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 37:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 38:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 39:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 40:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 41:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 42:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 43:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 44:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 45:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 46:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 47:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 48:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 49:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 50:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 51:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 52:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 53:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 54:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 55:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 56:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 57:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 58:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 59:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 60:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 61:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 62:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 63:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 64:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 65:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 66:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 67:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 68:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 69:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 70:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 71:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 72:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 73:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 74:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 75:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 76:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 77:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 78:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 79:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 80:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 81:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 82:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 83:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 84:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 85:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 86:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 87:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 88:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 89:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 90:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 91:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 92:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 93:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 94:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 95:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 96:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 97:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 98:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 99:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Geração 100:
# ****************************************************************************************************
# individuo = [0, 16, 17, 2], mapeamento= [[0, 3, 7, 13, 15, 16], [0, 3, 6, 12, 11, 17], [17, 14, 10, 7, 5, 2]],melhor pontuação: -2.8173537421354116
# Nao foi possivel mapear rede virtual

# %% [markdown]
# ### - Teste 4

# %%
# Definição do grafo de topologia virtual a ser mapeado
rd_virtual = nx.Graph()

rd_virtual.add_nodes_from([

    (0, {"cpu": 7}),
    (1, {"cpu": 6}),
    (2, {"cpu": 5}),
    (3, {"cpu": 8}),
    (4, {"cpu": 9}),

])

rd_virtual.add_weighted_edges_from([
    (0,1,4),(0,3,8),(0,2,11),
    (1,4,14),(1,2,9),(2,4,9),
    (2,3,10),(3,4,10),
    ]
)

# %%
plotar_rede(rd_virtual)

# %%
i = algoritimo_genetico(rd_fisica,rd_virtual)

n,e = consume_recursos(i[1],rd_fisica,rd_virtual)
# Out:
# Geração 1:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 2:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 3:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 4:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 5:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 6:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 7:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 8:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 9:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 10:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 11:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 12:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 13:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 14:
# ****************************************************************************************************
# individuo = [12, 15, 18, 17, 16], mapeamento= [[12, 8, 13, 15], [12, 11, 17], [12, 11, 14, 18], [15, 16], [15, 18], [18, 16], [18, 17], [17, 16]],melhor pontuação: 0.4945205479452055
# Geração 15:
# ****************************************************************************************************
# individuo = [19, 16, 15, 12, 18], mapeamento= [[19, 11, 17, 16], [19, 12], [19, 10, 14, 15], [16, 18], [16, 15], [15, 18], [15, 13, 8, 12], [12, 11, 14, 18]],melhor pontuação: 0.6087431693989072
# Geração 16:
# ****************************************************************************************************
# individuo = [19, 16, 15, 12, 18], mapeamento= [[19, 11, 17, 16], [19, 12], [19, 10, 14, 15], [16, 18], [16, 15], [15, 18], [15, 13, 8, 12], [12, 11, 14, 18]],melhor pontuação: 0.6087431693989072
# Geração 17:
# ****************************************************************************************************
# individuo = [19, 16, 15, 12, 18], mapeamento= [[19, 11, 17, 16], [19, 12], [19, 10, 14, 15], [16, 18], [16, 15], [15, 18], [15, 13, 8, 12], [12, 11, 14, 18]],melhor pontuação: 0.6087431693989072
# Geração 18:
# ****************************************************************************************************
# individuo = [19, 16, 15, 12, 18], mapeamento= [[19, 11, 17, 16], [19, 12], [19, 10, 14, 15], [16, 18], [16, 15], [15, 18], [15, 13, 8, 12], [12, 11, 14, 18]],melhor pontuação: 0.6087431693989072
# Geração 19:
# ****************************************************************************************************
# individuo = [19, 16, 15, 12, 18], mapeamento= [[19, 11, 17, 16], [19, 12], [19, 10, 14, 15], [16, 18], [16, 15], [15, 18], [15, 13, 8, 12], [12, 11, 14, 18]],melhor pontuação: 0.6087431693989072
# Geração 20:
# ****************************************************************************************************
# individuo = [19, 16, 15, 12, 18], mapeamento= [[19, 11, 17, 16], [19, 12], [19, 10, 14, 15], [16, 18], [16, 15], [15, 18], [15, 13, 8, 12], [12, 11, 14, 18]],melhor pontuação: 0.6087431693989072
# Geração 21:
# ****************************************************************************************************
# individuo = [19, 16, 15, 12, 18], mapeamento= [[19, 11, 17, 16], [19, 12], [19, 10, 14, 15], [16, 18], [16, 15], [15, 18], [15, 13, 8, 12], [12, 11, 14, 18]],melhor pontuação: 0.6087431693989072
# Geração 22:
# ****************************************************************************************************
# individuo = [19, 16, 15, 12, 18], mapeamento= [[19, 11, 17, 16], [19, 12], [19, 10, 14, 15], [16, 18], [16, 15], [15, 18], [15, 13, 8, 12], [12, 11, 14, 18]],melhor pontuação: 0.6087431693989072
# Geração 23:
# ****************************************************************************************************
# individuo = [19, 16, 15, 12, 18], mapeamento= [[19, 11, 17, 16], [19, 12], [19, 10, 14, 15], [16, 18], [16, 15], [15, 18], [15, 13, 8, 12], [12, 11, 14, 18]],melhor pontuação: 0.6087431693989072
# Geração 24:
# ****************************************************************************************************
# individuo = [19, 16, 15, 12, 18], mapeamento= [[19, 11, 17, 16], [19, 12], [19, 10, 14, 15], [16, 18], [16, 15], [15, 18], [15, 13, 8, 12], [12, 11, 14, 18]],melhor pontuação: 0.6087431693989072
# Geração 25:
# ****************************************************************************************************
# individuo = [16, 19, 15, 18, 12], mapeamento= [[16, 17, 11, 19], [16, 18], [16, 15], [19, 12], [19, 10, 14, 15], [15, 13, 8, 12], [15, 18], [18, 14, 11, 12]],melhor pontuação: 0.6102003642987249
# Geração 26:
# ****************************************************************************************************
# individuo = [16, 19, 15, 18, 12], mapeamento= [[16, 17, 11, 19], [16, 18], [16, 15], [19, 12], [19, 10, 14, 15], [15, 13, 8, 12], [15, 18], [18, 14, 11, 12]],melhor pontuação: 0.6102003642987249
# Geração 27:
# ****************************************************************************************************
# individuo = [16, 19, 15, 18, 12], mapeamento= [[16, 17, 11, 19], [16, 18], [16, 15], [19, 12], [19, 10, 14, 15], [15, 13, 8, 12], [15, 18], [18, 14, 11, 12]],melhor pontuação: 0.6102003642987249
# Geração 28:
# ****************************************************************************************************
# individuo = [16, 19, 15, 18, 12], mapeamento= [[16, 17, 11, 19], [16, 18], [16, 15], [19, 12], [19, 10, 14, 15], [15, 13, 8, 12], [15, 18], [18, 14, 11, 12]],melhor pontuação: 0.6102003642987249
# Geração 29:
# ****************************************************************************************************
# individuo = [16, 19, 15, 18, 12], mapeamento= [[16, 17, 11, 19], [16, 18], [16, 15], [19, 12], [19, 10, 14, 15], [15, 13, 8, 12], [15, 18], [18, 14, 11, 12]],melhor pontuação: 0.6102003642987249
# Geração 30:
# ****************************************************************************************************
# individuo = [16, 19, 15, 18, 12], mapeamento= [[16, 17, 11, 19], [16, 18], [16, 15], [19, 12], [19, 10, 14, 15], [15, 13, 8, 12], [15, 18], [18, 14, 11, 12]],melhor pontuação: 0.6102003642987249
# Geração 31:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 32:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 33:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 34:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 35:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 36:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 37:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 38:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 39:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 40:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 41:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 42:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 43:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 44:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 45:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 46:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 47:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 48:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 49:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 50:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 51:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 52:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 53:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 54:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 55:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 56:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 57:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 58:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 59:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 60:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 61:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 62:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 63:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 64:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 65:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 66:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 67:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 68:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 69:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 70:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 71:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 72:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 73:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 74:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 75:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 76:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 77:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 78:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 79:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 80:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 81:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 82:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 83:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 84:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 85:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 86:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 87:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 88:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 89:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 90:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 91:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 92:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 93:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 94:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 95:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 96:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 97:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 98:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 99:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745
# Geração 100:
# ****************************************************************************************************
# individuo = [12, 9, 6, 19, 10], mapeamento= [[12, 9], [12, 19], [12, 6], [9, 8, 10], [9, 6], [6, 7, 10], [6, 8, 19], [19, 10]],melhor pontuação: 8.246031746031745

# %%
plotar_rede_incorporada(rd_fisica,n,e)

# %% [markdown]
# ### - Teste 5

# %%
rd_virtual = nx.Graph()

rd_virtual.add_nodes_from([

    (0, {"cpu": 17}),
    (1, {"cpu": 16}),
    (2, {"cpu": 15}),
    (3, {"cpu": 18}),

    (4, {"cpu": 17}),
    (5, {"cpu": 16}),
    (6, {"cpu": 15}),
    (7, {"cpu": 18}),

])

rd_virtual.add_weighted_edges_from([
    (1,4,14),(2,4,8),(3,4,11),(5,4,14),
    (6,4,11),(7,4,14),(0,4,14)

    ]
)

# %%
plotar_rede(rd_virtual)

# %%
i= algoritimo_genetico(rd_fisica,rd_virtual)

n,e = consume_recursos(i[1],rd_fisica,rd_virtual)
# Out:
# Geração 1:
# ****************************************************************************************************
# individuo = [1, 3, 2, 10, 5, 7, 17, 12], mapeamento= [[1, 5], [3, 5], [2, 5], [10, 7, 5], [5, 7], [5, 4, 13, 14, 17], [5, 6, 12]],melhor pontuação: 0.4328767123287671
# Geração 2:
# ****************************************************************************************************
# individuo = [1, 3, 2, 10, 5, 7, 17, 12], mapeamento= [[1, 5], [3, 5], [2, 5], [10, 7, 5], [5, 7], [5, 4, 13, 14, 17], [5, 6, 12]],melhor pontuação: 0.4328767123287671
# Geração 3:
# ****************************************************************************************************
# individuo = [1, 3, 2, 10, 5, 7, 17, 12], mapeamento= [[1, 5], [3, 5], [2, 5], [10, 7, 5], [5, 7], [5, 4, 13, 14, 17], [5, 6, 12]],melhor pontuação: 0.4328767123287671
# Geração 4:
# ****************************************************************************************************
# individuo = [15, 4, 17, 0, 7, 6, 19, 2], mapeamento= [[15, 13, 7], [4, 7], [17, 14, 10, 7], [0, 3, 7], [7, 6], [7, 8, 19], [7, 5, 2]],melhor pontuação: 0.8050896471949104
# Geração 5:
# ****************************************************************************************************
# individuo = [10, 19, 7, 12, 8, 9, 13, 1], mapeamento= [[10, 8], [19, 8], [7, 8], [12, 8], [8, 9], [8, 13], [8, 6, 5, 1]],melhor pontuação: 13.492307692307692
# Geração 6:
# ****************************************************************************************************
# individuo = [10, 19, 7, 12, 8, 9, 13, 1], mapeamento= [[10, 8], [19, 8], [7, 8], [12, 8], [8, 9], [8, 13], [8, 6, 5, 1]],melhor pontuação: 13.492307692307692
# Geração 7:
# ****************************************************************************************************
# individuo = [10, 19, 7, 12, 8, 9, 13, 1], mapeamento= [[10, 8], [19, 8], [7, 8], [12, 8], [8, 9], [8, 13], [8, 6, 5, 1]],melhor pontuação: 13.492307692307692
# Geração 8:
# ****************************************************************************************************
# individuo = [10, 19, 7, 12, 8, 9, 13, 1], mapeamento= [[10, 8], [19, 8], [7, 8], [12, 8], [8, 9], [8, 13], [8, 6, 5, 1]],melhor pontuação: 13.492307692307692
# Geração 9:
# ****************************************************************************************************
# individuo = [10, 19, 7, 12, 8, 9, 13, 1], mapeamento= [[10, 8], [19, 8], [7, 8], [12, 8], [8, 9], [8, 13], [8, 6, 5, 1]],melhor pontuação: 13.492307692307692
# Geração 10:
# ****************************************************************************************************
# individuo = [10, 19, 7, 12, 8, 9, 13, 1], mapeamento= [[10, 8], [19, 8], [7, 8], [12, 8], [8, 9], [8, 13], [8, 6, 5, 1]],melhor pontuação: 13.492307692307692
# Geração 11:
# ****************************************************************************************************
# individuo = [10, 19, 7, 12, 8, 9, 13, 1], mapeamento= [[10, 8], [19, 8], [7, 8], [12, 8], [8, 9], [8, 13], [8, 6, 5, 1]],melhor pontuação: 13.492307692307692
# Geração 12:
# ****************************************************************************************************
# individuo = [10, 19, 7, 12, 8, 9, 13, 1], mapeamento= [[10, 8], [19, 8], [7, 8], [12, 8], [8, 9], [8, 13], [8, 6, 5, 1]],melhor pontuação: 13.492307692307692
# Geração 13:
# ****************************************************************************************************
# individuo = [10, 19, 7, 12, 8, 9, 13, 1], mapeamento= [[10, 8], [19, 8], [7, 8], [12, 8], [8, 9], [8, 13], [8, 6, 5, 1]],melhor pontuação: 13.492307692307692
# Geração 14:
# ****************************************************************************************************
# individuo = [10, 19, 7, 12, 8, 9, 13, 1], mapeamento= [[10, 8], [19, 8], [7, 8], [12, 8], [8, 9], [8, 13], [8, 6, 5, 1]],melhor pontuação: 13.492307692307692
# Geração 15:
# ****************************************************************************************************
# individuo = [10, 19, 7, 12, 8, 9, 13, 1], mapeamento= [[10, 8], [19, 8], [7, 8], [12, 8], [8, 9], [8, 13], [8, 6, 5, 1]],melhor pontuação: 13.492307692307692
# Geração 16:
# ****************************************************************************************************
# individuo = [13, 4, 14, 3, 7, 6, 2, 8], mapeamento= [[13, 7], [4, 7], [14, 10, 7], [3, 7], [7, 6], [7, 5, 2], [7, 8]],melhor pontuação: 14.553846153846154
# Geração 17:
# ****************************************************************************************************
# individuo = [13, 4, 14, 3, 7, 6, 2, 8], mapeamento= [[13, 7], [4, 7], [14, 10, 7], [3, 7], [7, 6], [7, 5, 2], [7, 8]],melhor pontuação: 14.553846153846154
# Geração 18:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 2], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5, 2]],melhor pontuação: 91.66666666666667
# Geração 19:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 2], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5, 2]],melhor pontuação: 91.66666666666667
# Geração 20:
# ****************************************************************************************************
# individuo = [13, 4, 6, 8, 7, 3, 10, 2], mapeamento= [[13, 7], [4, 7], [6, 7], [8, 7], [7, 3], [7, 10], [7, 5, 2]],melhor pontuação: 91.66666666666667
# Geração 21:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 22:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 23:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 24:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 25:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 26:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 27:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 28:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 29:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 30:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 31:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 32:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 33:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 34:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 35:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 36:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 37:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 38:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 39:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 40:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 41:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 42:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 43:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 44:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 45:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 46:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 47:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 48:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 49:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 50:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 51:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 52:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 53:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 54:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 55:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 56:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 57:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 58:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 59:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 60:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 61:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 62:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 63:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 64:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 65:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 66:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 67:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 68:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 69:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 70:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 71:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 72:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 73:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 74:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 75:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 76:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 77:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 78:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 79:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 80:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 81:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 82:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 83:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 84:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 85:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 86:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 87:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 88:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 89:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 90:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 91:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 92:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 93:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 94:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 95:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 96:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 97:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 98:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 99:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0
# Geração 100:
# ****************************************************************************************************
# individuo = [13, 4, 6, 3, 7, 8, 10, 5], mapeamento= [[13, 7], [4, 7], [6, 7], [3, 7], [7, 8], [7, 10], [7, 5]],melhor pontuação: 702.0

# %%
plotar_rede_incorporada(rd_fisica,n,e)

# %% [markdown]
# ### - Teste 5

# %% [markdown]
# ### Recebendo uma requisição de um arquivo json

# %%
import json

with open("requisicoes.json") as requsicao:
    req = json.load(requsicao)

# %% [markdown]
# ### Transformando requisição em um grafo

# %%
def cria_rede(requsicao):
    nos = []
    enlaces = []

    for no,cpu in requsicao['1']['nos'].items():
        nos.append((int(no),cpu))
    
    for enlace in requsicao['1']['enlaces'].values():
        enlace = enlace.split(",")
        enlaces.append((int(enlace[0]),int(enlace[1]),int(enlace[2])))
    
    rede =  nx.Graph()
    rede.add_nodes_from(nos)
    rede.add_weighted_edges_from(enlaces)

    return rede

# %%
rd = cria_rede(req)

# %%
plotar_rede(rd)

# %%
i,m = algoritimo_genetico(rd_fisica,rd)

n,e = consume_recursos(m,rd_fisica,rd)
# Out:
# Geração 1:
# ****************************************************************************************************
# individuo = [5, 4, 1, 13, 6, 12], mapeamento= [[5, 4], [5, 1], [4, 13], [4, 1], [13, 7, 6], [13, 8, 12], [6, 12]],melhor pontuação: 12.138461538461538
# Geração 2:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 3:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 4:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 5:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 6:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 7:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 8:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 9:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 10:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 11:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 12:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 13:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 14:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 15:
# ****************************************************************************************************
# individuo = [2, 6, 3, 8, 10, 13], mapeamento= [[2, 5, 6], [2, 3], [6, 8], [6, 3], [8, 10], [8, 13], [10, 13]],melhor pontuação: 76.44444444444444
# Geração 16:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 17:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 18:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 19:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 20:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 21:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 22:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 23:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 24:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 25:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 26:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 27:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 28:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 29:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 30:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 31:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 32:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 33:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 34:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 35:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 36:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 37:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 38:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 39:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 40:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 41:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 42:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 43:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 44:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 45:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 46:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 47:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 48:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 49:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 50:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 51:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 52:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 53:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 54:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 55:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 56:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 57:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 58:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 59:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 60:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 61:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 62:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 63:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 64:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 65:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 66:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 67:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 68:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 69:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 70:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 71:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 72:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 73:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 74:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 75:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 76:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 77:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 78:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 79:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 80:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 81:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 82:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 83:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 84:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 85:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 86:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 87:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 88:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 89:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 90:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 91:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 92:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 93:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 94:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 95:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 96:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 97:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 98:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 99:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0
# Geração 100:
# ****************************************************************************************************
# individuo = [18, 14, 17, 10, 19, 11], mapeamento= [[18, 14], [18, 17], [14, 10], [14, 17], [10, 19], [10, 11], [19, 11]],melhor pontuação: 816.0

# %%
plotar_rede_incorporada(rd_fisica,n,e)

# %% [markdown]
# ### - Teste 5

# %% [markdown]
# ### Recebendo uma requisição de um arquivo json

# %%
rd_virtual = nx.Graph()

rd_virtual.add_nodes_from([

           ( 0,{"cpu": 7}),
           ( 1,{"cpu": 6}),
           ( 2,{"cpu": 5}),
           ( 3,{"cpu": 8}),
           ( 4,{"cpu": 8}),
           ( 5,{"cpu": 8}),

])

rd_virtual.add_weighted_edges_from([
            (0,1,4),
            (0,2,11),
            (1,2,14),

            (3,4,10),
            (3,5,15),
            (5,4,16),

            (3,0,10),
            (1,4,15),
    ]
)

# %%
plotar_rede(rd_virtual)

# %%
i= algoritimo_genetico(rd_fisica,rd_virtual)

print(i)
# Out:
# Geração 1:
# ****************************************************************************************************
# individuo = [12, 13, 14, 6, 10, 19], mapeamento= [[12, 8, 13], [12, 11, 14], [12, 6], [13, 14], [13, 10], [6, 7, 10], [6, 8, 19], [10, 19]],melhor pontuação: 2.770348837209302
# Geração 2:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 3:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 4:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 5:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 6:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 7:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 8:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 9:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 10:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 11:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 12:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 13:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 14:
# ****************************************************************************************************
# individuo = [15, 14, 18, 12, 9, 6], mapeamento= [[15, 14], [15, 18], [15, 13, 8, 12], [14, 18], [14, 10, 8, 9], [12, 9], [12, 6], [9, 6]],melhor pontuação: 3.0319767441860463
# Geração 15:
# ****************************************************************************************************
# individuo = [8, 19, 10, 13, 11, 17], mapeamento= [[8, 19], [8, 10], [8, 13], [19, 10], [19, 11], [13, 10, 11], [13, 14, 17], [11, 17]],melhor pontuação: 30.571428571428573
# Geração 16:
# ****************************************************************************************************
# individuo = [8, 19, 10, 13, 11, 17], mapeamento= [[8, 19], [8, 10], [8, 13], [19, 10], [19, 11], [13, 10, 11], [13, 14, 17], [11, 17]],melhor pontuação: 30.571428571428573
# Geração 17:
# ****************************************************************************************************
# individuo = [8, 19, 10, 13, 11, 17], mapeamento= [[8, 19], [8, 10], [8, 13], [19, 10], [19, 11], [13, 10, 11], [13, 14, 17], [11, 17]],melhor pontuação: 30.571428571428573
# Geração 18:
# ****************************************************************************************************
# individuo = [8, 19, 10, 13, 11, 17], mapeamento= [[8, 19], [8, 10], [8, 13], [19, 10], [19, 11], [13, 10, 11], [13, 14, 17], [11, 17]],melhor pontuação: 30.571428571428573
# Geração 19:
# ****************************************************************************************************
# individuo = [8, 19, 10, 13, 11, 17], mapeamento= [[8, 19], [8, 10], [8, 13], [19, 10], [19, 11], [13, 10, 11], [13, 14, 17], [11, 17]],melhor pontuação: 30.571428571428573
# Geração 20:
# ****************************************************************************************************
# individuo = [8, 19, 10, 13, 11, 17], mapeamento= [[8, 19], [8, 10], [8, 13], [19, 10], [19, 11], [13, 10, 11], [13, 14, 17], [11, 17]],melhor pontuação: 30.571428571428573
# Geração 21:
# ****************************************************************************************************
# individuo = [8, 19, 10, 13, 11, 17], mapeamento= [[8, 19], [8, 10], [8, 13], [19, 10], [19, 11], [13, 10, 11], [13, 14, 17], [11, 17]],melhor pontuação: 30.571428571428573
# Geração 22:
# ****************************************************************************************************
# individuo = [8, 19, 10, 13, 11, 17], mapeamento= [[8, 19], [8, 10], [8, 13], [19, 10], [19, 11], [13, 10, 11], [13, 14, 17], [11, 17]],melhor pontuação: 30.571428571428573
# Geração 23:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 24:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 25:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 26:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 27:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 28:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 29:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 30:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 31:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 32:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 33:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 34:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 35:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 36:
# ****************************************************************************************************
# individuo = [8, 10, 19, 15, 14, 18], mapeamento= [[8, 10], [8, 19], [8, 13, 15], [10, 19], [10, 14], [15, 14], [15, 18], [14, 18]],melhor pontuação: 94.66666666666667
# Geração 37:
# ****************************************************************************************************
# individuo = [19, 10, 8, 17, 14, 18], mapeamento= [[19, 10], [19, 8], [19, 11, 17], [10, 8], [10, 14], [17, 14], [17, 18], [14, 18]],melhor pontuação: 96.88888888888889
# Geração 38:
# ****************************************************************************************************
# individuo = [19, 10, 8, 17, 14, 18], mapeamento= [[19, 10], [19, 8], [19, 11, 17], [10, 8], [10, 14], [17, 14], [17, 18], [14, 18]],melhor pontuação: 96.88888888888889
# Geração 39:
# ****************************************************************************************************
# individuo = [19, 10, 8, 17, 14, 18], mapeamento= [[19, 10], [19, 8], [19, 11, 17], [10, 8], [10, 14], [17, 14], [17, 18], [14, 18]],melhor pontuação: 96.88888888888889
# Geração 40:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 41:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 42:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 43:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 44:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 45:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 46:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 47:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 48:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 49:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 50:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 51:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 52:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 53:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 54:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 55:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 56:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 57:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 58:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 59:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 60:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 61:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 62:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 63:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 64:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 65:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 66:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 67:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 68:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 69:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 70:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 71:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 72:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 73:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 74:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 75:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 76:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 77:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 78:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 79:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 80:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 81:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 82:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 83:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 84:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 85:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 86:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 87:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 88:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 89:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 90:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 91:
# ****************************************************************************************************
# individuo = [19, 10, 8, 11, 14, 17], mapeamento= [[19, 10], [19, 8], [19, 11], [10, 8], [10, 14], [11, 14], [11, 17], [14, 17]],melhor pontuação: 704.0
# Geração 92:
# ****************************************************************************************************
# individuo = [10, 13, 8, 14, 15, 18], mapeamento= [[10, 13], [10, 8], [10, 14], [13, 8], [13, 15], [14, 15], [14, 18], [15, 18]],melhor pontuação: 712.0
# Geração 93:
# ****************************************************************************************************
# individuo = [10, 13, 8, 14, 15, 18], mapeamento= [[10, 13], [10, 8], [10, 14], [13, 8], [13, 15], [14, 15], [14, 18], [15, 18]],melhor pontuação: 712.0
# Geração 94:
# ****************************************************************************************************
# individuo = [10, 13, 8, 14, 15, 18], mapeamento= [[10, 13], [10, 8], [10, 14], [13, 8], [13, 15], [14, 15], [14, 18], [15, 18]],melhor pontuação: 712.0
# Geração 95:
# ****************************************************************************************************
# individuo = [10, 13, 8, 14, 15, 18], mapeamento= [[10, 13], [10, 8], [10, 14], [13, 8], [13, 15], [14, 15], [14, 18], [15, 18]],melhor pontuação: 712.0
# Geração 96:
# ****************************************************************************************************
# individuo = [10, 13, 8, 14, 15, 18], mapeamento= [[10, 13], [10, 8], [10, 14], [13, 8], [13, 15], [14, 15], [14, 18], [15, 18]],melhor pontuação: 712.0
# Geração 97:
# ****************************************************************************************************
# individuo = [10, 13, 8, 14, 15, 18], mapeamento= [[10, 13], [10, 8], [10, 14], [13, 8], [13, 15], [14, 15], [14, 18], [15, 18]],melhor pontuação: 712.0
# Geração 98:
# ****************************************************************************************************
# individuo = [10, 13, 8, 14, 15, 18], mapeamento= [[10, 13], [10, 8], [10, 14], [13, 8], [13, 15], [14, 15], [14, 18], [15, 18]],melhor pontuação: 712.0
# Geração 99:
# ****************************************************************************************************
# individuo = [10, 13, 8, 14, 15, 18], mapeamento= [[10, 13], [10, 8], [10, 14], [13, 8], [13, 15], [14, 15], [14, 18], [15, 18]],melhor pontuação: 712.0
# Geração 100:
# ****************************************************************************************************
# individuo = [10, 13, 8, 14, 15, 18], mapeamento= [[10, 13], [10, 8], [10, 14], [13, 8], [13, 15], [14, 15], [14, 18], [15, 18]],melhor pontuação: 712.0
# [[10, 13, 8, 14, 15, 18], [[10, 13], [10, 8], [10, 14], [13, 8], [13, 15], [14, 15], [14, 18], [15, 18]]]

# %%
n,e = consume_recursos(i[1],rd_fisica,rd_virtual)

# %%
plotar_rede_incorporada(rd_fisica,n,e)
